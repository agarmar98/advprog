# %%
import os
import getpass

usuario = getpass.getuser()

# os.environ['GDAL_DATA'] = f'/opt/anaconda3/envs/geoenv/share/gdal'
# os.environ['PROJ_LIB'] = f'/opt/anaconda3/envs/geoenv/share'

# en windows
os.environ['GDAL_DATA'] = f'C:\\Users\\{usuario}\\anaconda3\\envs\\advprog12\\Library\\share\\gdal'
os.environ['PROJ_LIB'] = f'C:\\Users\\{usuario}\\anaconda3\\envs\\advprog12\\Library\\share\\proj'

# %%
import sys

#sys.argv[1] = "C:\\Users\\angel\\Documents\\Programacion_avanzada\\practicas\\Geodatos\\" #Ángel
sys.argv[1] = "E:\\advprog\\p1\\Geodatos\\" #Edu

euc_points = sys.argv[1] + "eucaliptos_españa_puntos\\eucalyptus_points.csv"
euc_mfe = sys.argv[1] + "Eucaliptales_Cornisa_Cantabrica\\Eucaliptales_Cornisa_Cantabrica.shp"

# %%
import rasterio
import glob
import numpy as np
from rasterio.merge import merge
from rasterio.enums import Resampling

# %% [markdown]
# La siguiente celda genera una lista con las rutas de nuestras 4 imagenes que queremos transformar a multibanda.

# %%
import tkinter as tk
from tkinter import filedialog
import os

# Lista para almacenar las rutas seleccionadas
rutas = []

def select_folder():
    folder_selected = filedialog.askdirectory(initialdir=os.path.expanduser("~"))
    if folder_selected:
        folder_selected = folder_selected.replace("/", "\\")  # Reemplazar '/' por '\'
        rutas.append(folder_selected)
        update_listbox()

def update_listbox():
    listbox.delete(0, tk.END)
    for ruta in rutas:
        listbox.insert(tk.END, ruta)

def remove_selected():
    selected_index = listbox.curselection()
    if selected_index:
        rutas.pop(selected_index[0])
        update_listbox()

def finish_selection():
    root.destroy()

root = tk.Tk()
root.title("Seleccionar Carpetas")
root.geometry("500x400")

tk.Label(root, text="Selecciona una carpeta", font=("Arial", 12)).pack(pady=5)

button_select = tk.Button(root, text="Seleccionar Carpeta", command=select_folder, font=("Arial", 10))
button_select.pack(pady=5)

listbox = tk.Listbox(root, width=60, height=10)
listbox.pack(pady=5)

button_remove = tk.Button(root, text="Eliminar Seleccionada", command=remove_selected, font=("Arial", 10))
button_remove.pack(pady=5)

button_finish = tk.Button(root, text="Finalizar Selección", command=finish_selection, font=("Arial", 10))
button_finish.pack(pady=5)

root.mainloop()

# %%
rutas
# Out:
# ['E:\\advprog\\p1\\Geodatos\\imagenes\\S2C_MSIL2A_20250219T111131_N0511_R137_T30TUN_20250219T152713.SAFE\\GRANULE\\L2A_T30TUN_A002395_20250219T111258\\IMG_DATA\\R20m',
#  'E:\\advprog\\p1\\Geodatos\\imagenes\\S2C_MSIL2A_20250219T111131_N0511_R137_T30TUP_20250219T152713.SAFE\\GRANULE\\L2A_T30TUP_A002395_20250219T111258\\IMG_DATA\\R20m',
#  'E:\\advprog\\p1\\Geodatos\\imagenes\\S2C_MSIL2A_20250219T111131_N0511_R137_T30TVN_20250219T152713.SAFE\\GRANULE\\L2A_T30TVN_A002395_20250219T111258\\IMG_DATA\\R20m',
#  'E:\\advprog\\p1\\Geodatos\\imagenes\\S2C_MSIL2A_20250219T111131_N0511_R137_T30TVP_20250219T152713.SAFE\\GRANULE\\L2A_T30TVP_A002395_20250219T111258\\IMG_DATA\\R20m']

# %% [markdown]
# A continuacion, el codigo para añadir las rutas rapidamente con sys.argv[1] (caso concreto para estas imagenes)

# %%
ruta1 = "S2C_MSIL2A_20250219T111131_N0511_R137_T30TUN_20250219T152713.SAFE\\GRANULE\\L2A_T30TUN_A002395_20250219T111258\\IMG_DATA\\R20m"
ruta2 = "S2C_MSIL2A_20250219T111131_N0511_R137_T30TUP_20250219T152713.SAFE\\GRANULE\\L2A_T30TUP_A002395_20250219T111258\\IMG_DATA\\R20m"
ruta3 = "S2C_MSIL2A_20250219T111131_N0511_R137_T30TVN_20250219T152713.SAFE\\GRANULE\\L2A_T30TVN_A002395_20250219T111258\\IMG_DATA\\R20m"
ruta4 = "S2C_MSIL2A_20250219T111131_N0511_R137_T30TVP_20250219T152713.SAFE\\GRANULE\\L2A_T30TVP_A002395_20250219T111258\\IMG_DATA\\R20m"
rutas = []
rutas.append(ruta1)
rutas.append(ruta2)
rutas.append(ruta3)
rutas.append(ruta4)
rutas
# Out:
# ['S2C_MSIL2A_20250219T111131_N0511_R137_T30TUN_20250219T152713.SAFE\\GRANULE\\L2A_T30TUN_A002395_20250219T111258\\IMG_DATA\\R20m',
#  'S2C_MSIL2A_20250219T111131_N0511_R137_T30TUP_20250219T152713.SAFE\\GRANULE\\L2A_T30TUP_A002395_20250219T111258\\IMG_DATA\\R20m',
#  'S2C_MSIL2A_20250219T111131_N0511_R137_T30TVN_20250219T152713.SAFE\\GRANULE\\L2A_T30TVN_A002395_20250219T111258\\IMG_DATA\\R20m',
#  'S2C_MSIL2A_20250219T111131_N0511_R137_T30TVP_20250219T152713.SAFE\\GRANULE\\L2A_T30TVP_A002395_20250219T111258\\IMG_DATA\\R20m']

# %% [markdown]
# El siguiente genera las 4 imagenes en las distintas rutas.

# %%
salidas_raster = []
for i, ruta in enumerate(rutas):
    #raster_files = sorted(glob.glob(sys.argv[1] + "imagenes/" + ruta + "/*.jp2")) #en caso de usar la celda anterior usar esta linea para rutas.
    raster_files = sorted(glob.glob(ruta + "\\*.jp2"))
    
    if not raster_files:
        print(f"No se encontraron archivos en {ruta}")
        continue
    
    bands = []
    with rasterio.open(raster_files[0]) as src:
        meta = src.meta.copy()
        meta.update({"count": len(raster_files), "driver": "GTiff"})
    
    for file in raster_files:
        with rasterio.open(file) as src:
            bands.append(src.read(1))
    
    stacked_array = np.stack(bands)
    output_tif = sys.argv[1] + "imagenes/" + ruta + "/salida/imagen_combinada_" + str(i+1) + ".tif"
    
    with rasterio.open(output_tif, "w", **meta) as dst:
        for j in range(stacked_array.shape[0]):
            dst.write(stacked_array[j], j + 1)
    salidas_raster.append(output_tif)
    print(f"Archivo guardado en: {output_tif}")
# Out:
# Archivo guardado en: E:\advprog\p1\Geodatos\imagenes/S2C_MSIL2A_20250219T111131_N0511_R137_T30TUN_20250219T152713.SAFE\GRANULE\L2A_T30TUN_A002395_20250219T111258\IMG_DATA\R20m/salida/imagen_combinada_1.tif
# Archivo guardado en: E:\advprog\p1\Geodatos\imagenes/S2C_MSIL2A_20250219T111131_N0511_R137_T30TUP_20250219T152713.SAFE\GRANULE\L2A_T30TUP_A002395_20250219T111258\IMG_DATA\R20m/salida/imagen_combinada_2.tif
# Archivo guardado en: E:\advprog\p1\Geodatos\imagenes/S2C_MSIL2A_20250219T111131_N0511_R137_T30TVN_20250219T152713.SAFE\GRANULE\L2A_T30TVN_A002395_20250219T111258\IMG_DATA\R20m/salida/imagen_combinada_3.tif
# Archivo guardado en: E:\advprog\p1\Geodatos\imagenes/S2C_MSIL2A_20250219T111131_N0511_R137_T30TVP_20250219T152713.SAFE\GRANULE\L2A_T30TVP_A002395_20250219T111258\IMG_DATA\R20m/salida/imagen_combinada_4.tif

# %% [markdown]
# Ahora quedaría hacer el mosaico. He pensado que se puede hacer lo mismo para las rutas,
# o en el bucle anterior una modificacion para que añada la ruta a otra lista. Lo haré en otro momentou

# %%
salidas_raster
# Out:
# ['E:\\advprog\\p1\\Geodatos\\imagenes/S2C_MSIL2A_20250219T111131_N0511_R137_T30TUN_20250219T152713.SAFE\\GRANULE\\L2A_T30TUN_A002395_20250219T111258\\IMG_DATA\\R20m/salida/imagen_combinada_1.tif',
#  'E:\\advprog\\p1\\Geodatos\\imagenes/S2C_MSIL2A_20250219T111131_N0511_R137_T30TUP_20250219T152713.SAFE\\GRANULE\\L2A_T30TUP_A002395_20250219T111258\\IMG_DATA\\R20m/salida/imagen_combinada_2.tif',
#  'E:\\advprog\\p1\\Geodatos\\imagenes/S2C_MSIL2A_20250219T111131_N0511_R137_T30TVN_20250219T152713.SAFE\\GRANULE\\L2A_T30TVN_A002395_20250219T111258\\IMG_DATA\\R20m/salida/imagen_combinada_3.tif',
#  'E:\\advprog\\p1\\Geodatos\\imagenes/S2C_MSIL2A_20250219T111131_N0511_R137_T30TVP_20250219T152713.SAFE\\GRANULE\\L2A_T30TVP_A002395_20250219T111258\\IMG_DATA\\R20m/salida/imagen_combinada_4.tif']

# %% [markdown]
# Las rutas se añaden al objeto "salidas raster"

# %%
from rasterio.merge import merge

# Abrimos los archivos de salida
src_files_to_mosaic = [rasterio.open(file) for file in salidas_raster]

# juntamos las imagnees con merge
mosaic, out_transform = merge(src_files_to_mosaic, method="first")  # "first" prioriza el primer píxel encontrado

# copiamos los metadatos
out_meta = src_files_to_mosaic[0].meta.copy()
out_meta.update({
    "height": mosaic.shape[1],  
    "width": mosaic.shape[2],   
    "transform": out_transform  
})

# Guardar la imagen final
output_tif = sys.argv[1] + "imagenes\\mosaico.tif"
with rasterio.open(output_tif, "w", **out_meta) as dest:
    for i in range(mosaic.shape[0]):  # (Para mantener el orden de las bandas)
        dest.write(mosaic[i], i + 1)

print(f"Mosaico guardado en: {output_tif}")

# Y cerrar los rasters
for src in src_files_to_mosaic:
    src.close()
# Out:
# Mosaico guardado en: E:\advprog\p1\Geodatos\imagenes\mosaico.tif

# %%
import rasterio
import geopandas as gpd
from rasterio.mask import mask
from shapely.geometry import mapping

# rutas
output_tif = sys.argv[1] + "imagenes\\mosaico.tif"
shapefile_path = sys.argv[1] + "shp_cantabria\\cantabria.shp"
output_path = sys.argv[1] + "resultados\\recorte_final.tif"


# Cargar shapefile
shapefile = gpd.read_file(shapefile_path)

# Abrir el ráster para obtener su SRC
with rasterio.open(output_tif) as src:
    raster_crs = src.crs  # Obtener CRS del ráster

# Reproyección del shapefile al SRC del ráster si fuera necesario (en este caso lo es)
if shapefile.crs != raster_crs:
    shapefile = shapefile.to_crs(raster_crs)

# Convertir geometría a formato GeoJSON (con shapely)
geometries = [mapping(geom) for geom in shapefile.geometry]

# Abrir el ráster y recortar
with rasterio.open(output_tif) as src:
    out_image, out_transform = mask(src, geometries, crop=True, all_touched=True)

    out_meta = src.meta.copy()
    out_meta.update({
        "driver": "GTiff",
        "height": out_image.shape[1],
        "width": out_image.shape[2],
        "transform": out_transform
    })

    # Guardar el nuevo ráster
    with rasterio.open(output_path, "w", **out_meta) as dest:
        dest.write(out_image)

print(f"✅ Recorte guardado en: {output_path}")
# Out:
# ✅ Recorte guardado en: E:\advprog\p1\Geodatos\resultados\recorte_final.tif

# %%
import rasterio
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

image_path = sys.argv[1] + "resultados\\recorte_final.tif"

with rasterio.open(image_path) as src:
    num_bandas = src.count  
    perfil = src.profile  
    print(f"Número de bandas: {num_bandas}")
    print(f"Dimensiones: {src.width}x{src.height}")
    print(f"Tipo de dato: {src.dtypes[0]}")
    
    # Leer todas las bandas en una matriz
    bandas = [src.read(i + 1) for i in range(num_bandas)]

# 📌 2. Visualizar algunas bandas (ej: las 3 primeras)
fig, axes = plt.subplots(1, 3, figsize=(15, 5))
for i, ax in enumerate(axes):
    ax.imshow(bandas[i], cmap="gray")
    ax.set_title(f"Banda {i+1}")
plt.show()

# 📌 3. Calcular estadísticas básicas de cada banda
stats = []
for i, banda in enumerate(bandas):
    stats.append([i + 1, np.min(banda), np.max(banda), np.mean(banda), np.std(banda)])

df_stats = pd.DataFrame(stats, columns=["Banda", "Mínimo", "Máximo", "Media", "Desviación estándar"])
print(df_stats)

# 📌 4. Histogramas de distribución de píxeles (ejemplo con primeras 6 bandas)
fig, axes = plt.subplots(2, 3, figsize=(15, 10))
for i, ax in enumerate(axes.ravel()):
    if i >= num_bandas:
        break
    ax.hist(bandas[i].ravel(), bins=50, color="blue", alpha=0.7)
    ax.set_title(f"Histograma Banda {i+1}")
plt.show()

# 📌 5. Calcular matriz de correlación entre bandas
matriz_corr = np.corrcoef([banda.ravel() for banda in bandas])

# 📌 6. Visualizar la matriz de correlación como un heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(matriz_corr, annot=True, fmt=".2f", cmap="coolwarm", xticklabels=range(1, num_bandas+1), yticklabels=range(1, num_bandas+1))
plt.title("Correlación entre Bandas")
plt.show()
# Out:
# Número de bandas: 14
# Dimensiones: 6924x4182
# Tipo de dato: uint16
#     Banda  Mínimo  Máximo        Media  Desviación estándar
# 0       1       0     209    53.435485            60.772970
# 1       2       0   20273   801.919345          1280.940486
# 2       3       0   20524   813.671590          1272.821773
# 3       4       0   19146   891.749437          1288.900626
# 4       5       0   18224   894.491407          1286.592015
# 5       6       0   17799  1123.476053          1482.676414
# 6       7       0   17701  1531.273496          1872.180863
# 7       8       0   17546  1660.598923          2003.156764
# 8       9       0   16345  1489.931780          1777.956226
# 9      10       0   16198  1092.479181          1356.180370
# 10     11       0   17306  1809.972575          2150.968447
# 11     12       0      11     2.185073             2.694919
# 12     13       0     255    37.039577            55.720445
# 13     14       0    4548   575.577121           648.874372

# %%
import rasterio
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import sys
import os

image_path = sys.argv[1] + "resultados\\recorte_final.tif"
out_dir = sys.argv[1] + "resultados\\EDA_outputs"
os.makedirs(out_dir, exist_ok=True)

with rasterio.open(image_path) as src:
    num_bandas = src.count  
    perfil = src.profile  
    print(f"Número de bandas: {num_bandas}")
    print(f"Dimensiones: {src.width}x{src.height}")
    print(f"Tipo de dato: {src.dtypes[0]}")
    
    # Leer todas las bandas en una lista
    bandas = [src.read(i + 1) for i in range(num_bandas)]

# 📌 1. Guardar imágenes individuales de cada banda
for i, banda in enumerate(bandas):
    plt.imshow(banda, cmap="gray")
    plt.title(f"Banda {i+1}")
    plt.axis("off")
    plt.savefig(os.path.join(out_dir, f"banda_{i+1}.png"), bbox_inches='tight')
    plt.close()

# 📌 2. Estadísticas básicas de cada banda
stats = []
for i, banda in enumerate(bandas):
    valores_validos = banda[banda > 0]  # Excluir valores 0
    p2, p98 = np.percentile(valores_validos, [2, 98])  # Percentiles 2 y 98
    stats.append([i + 1, np.min(valores_validos), np.max(valores_validos), np.mean(valores_validos), np.std(valores_validos), p2, p98])

df_stats = pd.DataFrame(stats, columns=["Banda", "Mínimo", "Máximo", "Media", "Desviación estándar", "P2", "P98"])
print(df_stats)

df_stats.to_csv(os.path.join(out_dir, "estadisticas_bandas.csv"), index=False)

# 📌 3. Histogramas ajustados por percentil 98
for i, banda in enumerate(bandas):
    valores_validos = banda[banda > 0]  # Excluir valores 0
    p2, p98 = np.percentile(valores_validos, [2, 98])  # Calcular percentiles
    
    plt.figure(figsize=(8, 5))
    plt.hist(valores_validos.ravel(), bins=50, range=(p2, p98), color="blue", alpha=0.7)
    plt.title(f"Histograma Banda {i+1} (Sin 0, P2-P98)")
    plt.xlabel("Valor de píxel")
    plt.ylabel("Frecuencia")
    plt.savefig(os.path.join(out_dir, f"histograma_banda_{i+1}.png"), bbox_inches='tight')
    plt.close()

# 📌 4. Matriz de correlación entre bandas
matriz_corr = np.corrcoef([banda[banda > 0].ravel() for banda in bandas])

# 📌 5. Visualizar y guardar la matriz de correlación
plt.figure(figsize=(10, 8))
sns.heatmap(matriz_corr, annot=True, fmt=".2f", cmap="coolwarm", xticklabels=range(1, num_bandas+1), yticklabels=range(1, num_bandas+1))
plt.title("Correlación entre Bandas")
plt.savefig(os.path.join(out_dir, "correlacion_bandas.png"), bbox_inches='tight')
plt.show()
# Out:
# Número de bandas: 14
# Dimensiones: 6924x4182
# Tipo de dato: uint16
#     Banda  Mínimo  Máximo        Media  Desviación estándar      P2      P98
# 0       1      72     209   115.971447            27.628403    82.0   180.00
# 1       2       1   20273  1740.411777          1388.414996  1094.0  7185.00
# 2       3     833   20524  1765.917765          1354.427364  1113.0  7080.00
# 3       4     952   19146  1935.370723          1259.230661  1216.0  6806.00
# 4       5     973   18224  1941.321641          1249.126698  1195.0  6705.74
# 5       6     396   17799  2438.288795          1251.062775  1370.0  7086.00
# 6       7     437   17701  3323.334751          1285.084449  1562.0  7234.00
# 7       8     512   17546  3604.010728          1305.595752  1617.0  7178.00
# 8       9    1022   16345  3233.610503          1105.551236  1536.0  6526.00
# 9      10     959   16198  2371.016045           979.925148  1305.0  5691.00
# 10     11     501   17306  3928.197525          1311.671267  1705.0  7314.00
# 11     12       2      11     4.742280             1.906581     2.0    10.00
# 12     13       1     255    80.387280            57.041196    20.0   255.00
# 13     14      47    4548  1249.179492           268.945469   701.0  1834.00

# %% [markdown]
# A continuación vamos a generar graficos y estadisticas basicas de la imagen. CAbe mencionar que excluiremos el valor "0", ya que es el que tienen los pixeles que no forman parte de la Comunidad Autónoma de Cantabria. Primero generaremos una tabla de estadisticas básicas de la imagen, en la que mostraremos el maximo, minimo, media, desviacion estándar, y los maximos y minimos de los percentiles 2 y 98, por si hubiera algunos valores erróneos.
#
# Despues vamos a generar las imagenes de cada una de las bandas en una composición blanco y negro, para los valores mas altos y bajos respectivamente. Esto nos dará una visión espacial general de las zonas en las que hay valores mas altos de reflectividad en las diferentes bandas.
#
# Tras esto generaremos los histogramas de cada una de las bandas, para observar como se distribuyen los valores de reflectividad en cada una.
#
# Finalmente haremos una matriz de correlacion de las imagenes.

# %%
import rasterio
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sys

image_path = sys.argv[1] + "resultados\\recorte_final.tif"

# Abrir la imagen y leer las bandas
with rasterio.open(image_path) as src:
    num_bandas = src.count  
    bandas = [src.read(i + 1) for i in range(num_bandas)]
    
#Estadisticas básicas:
stats = []
for i, banda in enumerate(bandas):
    valores_validos = banda[banda > 0]  # Excluir valores 0
    p2, p98 = np.percentile(valores_validos, [2, 98])  # Percentiles 2 y 98
    stats.append([i + 1, np.min(valores_validos), np.max(valores_validos), np.mean(valores_validos), np.std(valores_validos), p2, p98])

df_stats = pd.DataFrame(stats, columns=["Banda", "Mínimo", "Máximo", "Media", "Desviación estándar", "P2", "P98"])
print(df_stats)

#Matriz de correlación:
matriz_corr = np.corrcoef([banda[banda > 0].ravel() for banda in bandas])

plt.figure(figsize=(10, 8))
sns.heatmap(matriz_corr, annot=True, fmt=".2f", cmap="coolwarm", xticklabels=range(1, num_bandas+1), yticklabels=range(1, num_bandas+1))
plt.title("Correlación entre Bandas")
plt.show()


# Imagenes de las bandas
fig, axes = plt.subplots((num_bandas // 3) + (num_bandas % 3 > 0), 3, figsize=(15, 5 * ((num_bandas // 3) + (num_bandas % 3 > 0))))
axes = axes.ravel()

for i in range(num_bandas):
    axes[i].imshow(bandas[i], cmap="gray")
    axes[i].set_title(f"Banda {i+1}")
    axes[i].axis("off")

# Para eliminar los huecos vacios de la ultima fila, en la que no hay 3 graficos:
for j in range(i + 1, len(axes)):
    axes[j].axis("off")

plt.tight_layout()
plt.show()

# Histogramas
fig, axes = plt.subplots((num_bandas // 3) + (num_bandas % 3 > 0), 3, figsize=(15, 5 * ((num_bandas // 3) + (num_bandas % 3 > 0))))
axes = axes.ravel()

for i in range(num_bandas):
    datos_validos = bandas[i][bandas[i] > 0]  # Ignorar ceros
    if datos_validos.size > 0:
        min_val, max_val = np.percentile(datos_validos, [2, 98])  # Usar percentiles 2 y 98
        axes[i].hist(datos_validos.ravel(), bins=50, color="blue", alpha=0.7, range=(min_val, max_val))
        axes[i].set_title(f"Histograma Banda {i+1}")

# Para los huecos vacios, de nuevo, en la ultima fiala:
for j in range(i + 1, len(axes)):
    axes[j].axis("off")

plt.tight_layout()
plt.show()
# Out:
#     Banda  Mínimo  Máximo        Media  Desviación estándar      P2      P98
# 0       1      72     209   115.971447            27.628403    82.0   180.00
# 1       2       1   20273  1740.411777          1388.414996  1094.0  7185.00
# 2       3     833   20524  1765.917765          1354.427364  1113.0  7080.00
# 3       4     952   19146  1935.370723          1259.230661  1216.0  6806.00
# 4       5     973   18224  1941.321641          1249.126698  1195.0  6705.74
# 5       6     396   17799  2438.288795          1251.062775  1370.0  7086.00
# 6       7     437   17701  3323.334751          1285.084449  1562.0  7234.00
# 7       8     512   17546  3604.010728          1305.595752  1617.0  7178.00
# 8       9    1022   16345  3233.610503          1105.551236  1536.0  6526.00
# 9      10     959   16198  2371.016045           979.925148  1305.0  5691.00
# 10     11     501   17306  3928.197525          1311.671267  1705.0  7314.00
# 11     12       2      11     4.742280             1.906581     2.0    10.00
# 12     13       1     255    80.387280            57.041196    20.0   255.00
# 13     14      47    4548  1249.179492           268.945469   701.0  1834.00
